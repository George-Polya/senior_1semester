# %%
import pandas as pd
import os
from glob import glob
from PIL import Image
import matplotlib.pyplot as plt

# %%
csvFile_path = os.listdir()[1]
csvFile_path
# Out:
# 'hanssem_product_images.UTF-8.csv'

# %%
df = pd.read_csv(csvFile_path)
test_url = df["IMG_URL"][0]

# %%
df["IMG_URL"]
# Out:
# 0        https://image.hanssem.com/hsimg//gds/550/578/5...
# 1        https://image.hanssem.com/hsimg//gds/550/578/5...
# 2        https://image.hanssem.com/hsimg//gds/550/543/5...
# 3        https://image.hanssem.com/hsimg//gds/550/543/5...
# 4        https://image.hanssem.com/hsimg//gds/550/543/5...
#                                ...
# 67042    https://image.hanssem.com/hsimg//gds/550/658/6...
# 67043    https://image.hanssem.com/hsimg//gds/550/658/6...
# 67044    https://image.hanssem.com/hsimg//gds/550/658/6...
# 67045    https://image.hanssem.com/hsimg//gds/550/658/6...
# 67046    https://image.hanssem.com/hsimg//gds/550/658/6...
# Name: IMG_URL, Length: 67047, dtype: object

# %%
from urllib import request
from io import BytesIO
import numpy as np

imgs = []
for url in df["IMG_URL"]:
    res = request.urlopen(url).read()
    img = Image.open(BytesIO(res))
    plt.imshow(img)
    # img = np.array(img)
    # imgs.append(img)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-80-d4eeb976b881> in <module>
#       5 imgs = []
#       6 for url in df["IMG_URL"]:
# ----> 7     res = request.urlopen(url).read()
#       8     img = Image.open(BytesIO(res))
#       9     plt.imshow(img)
#
# C:\ProgramData\Anaconda3\lib\http\client.py in read(self, amt)
#     458             else:
#     459                 try:
# --> 460                     s = self._safe_read(self.length)
#     461                 except IncompleteRead:
#     462                     self._close_conn()
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _safe_read(self, amt)
#     608         s = []
#     609         while amt > 0:
# --> 610             chunk = self.fp.read(min(amt, MAXAMOUNT))
#     611             if not chunk:
#     612                 raise IncompleteRead(b''.join(s), amt)
#
# C:\ProgramData\Anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# C:\ProgramData\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1050                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1051                   self.__class__)
# -> 1052             return self.read(nbytes, buffer)
#    1053         else:
#    1054             return super().recv_into(buffer, nbytes, flags)
#
# C:\ProgramData\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     909         try:
#     910             if buffer is not None:
# --> 911                 return self._sslobj.read(len, buffer)
#     912             else:
#     913                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import pickle
with open("hanssem_product_images", "wb") as fw:
    pickle.dump(imgs,fw)
