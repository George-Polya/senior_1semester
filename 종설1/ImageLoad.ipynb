# %%
import pandas as pd
import os
from glob import glob
from PIL import Image
import matplotlib.pyplot as plt
import cv2

from urllib import request
import urllib
from io import BytesIO
import numpy as np
from skimage import io

# %%
csvFile_path = os.listdir()[2]
csvFile_path
# Out:
# 'hanssem_product_images.UTF-8.csv'

# %%
df = pd.read_csv(csvFile_path)
test_url = df["IMG_URL"][0]

# %%
image = io.imread(test_url)
plt.imshow(image)

# %%
from tqdm import tqdm
imgs = []
passed_urlIndex = []

for i in tqdm(df.index):
    try:
        with request.urlopen(df["IMG_URL"][i]) as res:
            img = np.array(Image.open(BytesIO(res.read())))
            imgs.append(img)
    except:
        imgs.append(i)
# Out:
#   4%|▍         | 2958/67047 [04:50<56:03, 19.05it/s]

# %%
plt.imshow(imgs[2]) # len(imgs) 67030
