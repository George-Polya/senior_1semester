# %% [markdown]
# # **Week01** Introduction to Programming Environment

# %% [markdown]
# - Write and run the code below in jupyter notebook (use Week01_given_code.ipynb), rename the file, and summit the file to e-class
# - Submit file name : Week01_\< id \>_ \< name \>.ipynb{ color: blue }
# - Due : tomorrow(Friday) 11:59pm

# %% [markdown]
# - **Student ID** : 2016112158
# - **Name** : KimHeeSu

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Markdown
# - When you press the escape key(or crtl + M), cell cursor color will be change from green to blue. This is **command mode**.
#    > cf. **Edit mode**
#    when cell cursor color is green. In Edit mode you can edit and run your code.
#    you can enter this mode by press crtl + Y or Enter
# - In Command Mode, you can edit this document using Markdown language.
# - Below are frequently used Markdown language.

# %% [markdown]
# # 1. Headers

# %% [markdown]
# ---
# # Header 1

# %% [markdown]
# Header 1
# ===

# %% [markdown]
# ---
# ## Header 2

# %% [markdown]
# Header 2
# ---

# %% [markdown]
# ---
# # Header 1
# ## Header 2
# ### Header 3
# #### Header 4
# ##### Header 5
# ###### Header 6

# %%
# Header 1
## Header 2
### Header 3
#### Header 4
##### Header 5
###### Header 6

# %% [markdown]
# ---
# # 2. Lists
# ## Unordered

# %% [markdown]
# * Item 1
# * Item 2
#   * Item 2a
#   * Item 2b

# %%
* Item 1
* Item 2
  * Item 2a
  * Item 2b

# %% [markdown]
# ## Orded
# 1. Item 1
# 1. Item 2
# 1. Item 3
#    1. Item 3a
#    1. Item 3b

# %% [markdown]
# 1. Item 1
# 1. Item 2
# 1. Item 3
#    1. Item 3a
#    1. Item 3b

# %% [markdown]
# cf. To enter a line break, you must press the Space key twice and then the Enter key.
# - ex)
# - code
#   > `"Hello,[space][space][enter] firend"`

# %% [markdown]
# - output
#   > "Hello
#   firend"

# %% [markdown]
# In addition, there are other syntaxes such as emphasis and code blocks, ... etc.
# If you want to know more, check out the link below.
# [Github Guides : Marstering Markdown](https://guides.github.com/features/mastering-markdown/)

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Keyboard Shotcuts

# %%
from IPython.display import Image
Image(filename='image.jpg')

# %% [markdown]
# ### 1. Run cell, Select below : Shift + Enter
# ### 2. Run cell :  Ctrl + Enter
# ### 3. Run cell, insert below : Alt + Enter
# ### 4. Copy selected cells : C
# ### 5. Cut  selected cells : X
# ### 6. Paste selected cells : V
# ### 7. Delete selected cells : D, D
# ### 8. Insert cell above : A
# ### 9. Insert cell below : B
# ### 10. Interrupt the kernel : i, i

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Check your library version

# %%
import pandas as pd
import numpy as np
import matplotlib
import sklearn

print(pd.__version__)
print(np.__version__)
print(matplotlib.__version__)
print(sklearn.__version__)
# Out:
# 1.2.1
# 1.19.5
# 3.3.2
# 0.23.2

# %% [markdown]
# # Test Code

# %%
print("Hello World")
x = 30
y = 20
print(x+y)
print(x-y)
print(x*y)
print(x / y)
print (x**y)
# Out:
# Hello World
# 50
# 10
# 600
# 1.5
# 348678440100000000000000000000
