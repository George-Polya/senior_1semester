# %%
from sklearn.datasets import fetch_olivetti_faces

faces = fetch_olivetti_faces()

X = faces.data
y = faces.target

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=1)

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train_std = scaler.transform(X_train)
X_test_std = scaler.transform(X_test)

# %%
X[0].shape
# Out:
# (4096,)

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
fig = plt.figure(figsize=(10, 4))
for i in range(30):
    ax = fig.add_subplot(3, 10, i + 1, xticks=[], yticks=[])
    ax.imshow(faces.images[i], cmap=plt.cm.bone)

# %%
mlp = MLPClassifier(hidden_layer_sizes=(200,200), max_iter=100, alpha=1e-5, solver="sgd", learning_rate_init=0.01,verbose=1,random_state=5)

# %%
mlp.fit(X_train_std, y_train)
# Out:
# Iteration 1, loss = 4.04352889
# Iteration 2, loss = 3.11399226
# Iteration 3, loss = 2.29835186
# Iteration 4, loss = 1.62228597
# Iteration 5, loss = 1.10857245
# Iteration 6, loss = 0.71299520
# Iteration 7, loss = 0.44661876
# Iteration 8, loss = 0.27864116
# Iteration 9, loss = 0.17348120
# Iteration 10, loss = 0.10997186
# Iteration 11, loss = 0.07142535
# Iteration 12, loss = 0.04833766
# Iteration 13, loss = 0.03372623
# Iteration 14, loss = 0.02490706
# Iteration 15, loss = 0.01953009
# Iteration 16, loss = 0.01542031
# Iteration 17, loss = 0.01269634
# Iteration 18, loss = 0.01068817
# Iteration 19, loss = 0.00926808
# Iteration 20, loss = 0.00812786
# Iteration 21, loss = 0.00730530
# Iteration 22, loss = 0.00662234
# Iteration 23, loss = 0.00611585
# Iteration 24, loss = 0.00567466
# Iteration 25, loss = 0.00533285
# Iteration 26, loss = 0.00504955
# Iteration 27, loss = 0.00481839
# Iteration 28, loss = 0.00461566
# Iteration 29, loss = 0.00443922
# ...

# %%
print("Training set score: %f" % mlp.score(X_train_std, y_train))
print("Test set score: %f" % mlp.score(X_test_std, y_test))
# Out:
# Training set score: 1.000000
# Test set score: 0.925000
