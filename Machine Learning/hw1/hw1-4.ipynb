# %% [markdown]
# #  Matplotlib : Plot y=〖2t〗^3+500 for t = 0,0.5,1.0,1.5,… ,8.5,9.0,9.5 with red triangles.

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.arange(0, 10, 0.5)
y = 2 * t**3 + 500
plt.plot(t, y, "r^")
plt.show()
